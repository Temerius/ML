# %% [markdown]
# <a href="https://colab.research.google.com/github/Temerius/ML/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pandas as pd
import random

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()

# %%
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']
X.shape, y.shape, names, feature_names
# Out:
# ((150, 4),
#  (150,),
#  array(['setosa', 'versicolor', 'virginica'], dtype='<U10'),
#  ['sepal length (cm)',
#   'sepal width (cm)',
#   'petal length (cm)',
#   'petal width (cm)'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
d = {feature_names[i]: X_train[:,i] for i in range(4)}
iris_info = pd.DataFrame(d)
iris_info
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  4.9               3.1                1.5               0.1
# 1                  5.9               3.2                4.8               1.8
# 2                  5.8               2.8                5.1               2.4
# 3                  4.6               3.6                1.0               0.2
# 4                  5.5               2.4                3.8               1.1
# ..                 ...               ...                ...               ...
# 115                5.2               3.5                1.5               0.2
# 116                5.0               2.0                3.5               1.0
# 117                6.7               2.5                5.8               1.8
# 118                7.1               3.0                5.9               2.1
# 119                5.0               3.5                1.3               0.3
#
# [120 rows x 4 columns]

# %%
target_names = [names[y_train[i]] for i in range(X_train.shape[0])]
iris_info['labels'] = y_train
iris_info['labels_name'] = target_names
iris_info
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  4.9               3.1                1.5               0.1
# 1                  5.9               3.2                4.8               1.8
# 2                  5.8               2.8                5.1               2.4
# 3                  4.6               3.6                1.0               0.2
# 4                  5.5               2.4                3.8               1.1
# ..                 ...               ...                ...               ...
# 115                5.2               3.5                1.5               0.2
# 116                5.0               2.0                3.5               1.0
# 117                6.7               2.5                5.8               1.8
# 118                7.1               3.0                5.9               2.1
# 119                5.0               3.5                1.3               0.3
#
#      labels labels_name
# 0         0      setosa
# 1         1  versicolor
# 2         2   virginica
# 3         0      setosa
# 4         1  versicolor
# ..      ...         ...
# 115       0      setosa
# 116       1  versicolor
# 117       2   virginica
# 118       2   virginica
# 119       0      setosa
#
# [120 rows x 6 columns]

# %%
iris_info.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         120.000000        120.000000         120.000000
# mean            5.859167          3.057500           3.813333
# std             0.796262          0.412751           1.730154
# min             4.400000          2.000000           1.000000
# 25%             5.175000          2.800000           1.600000
# 50%             5.800000          3.000000           4.400000
# 75%             6.400000          3.300000           5.100000
# max             7.700000          4.400000           6.700000
#
#        petal width (cm)      labels
# count        120.000000  120.000000
# mean           1.222500    1.016667
# std            0.757535    0.809433
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
def knn_classifier(object_to_classify, k, plan_matrix, targets):
    distances = torch.sum((object_to_classify.unsqueeze(0) - plan_matrix) ** 2, dim=1)
    _, min_indices = torch.topk(distances, k=k, largest=False)
    k_labels = targets[min_indices]
    label, _ = torch.mode(torch.tensor(k_labels))
    #print(min_indices, k_labels, label, distances)
    return label

# %%
def fn_accuracy(true_labels, pred_labels):
    tmp1 = torch.eq(true_labels, pred_labels).sum()
    tmp2 = tmp1.item() / len(pred_labels)
    return tmp2 * 100

# %%
pred_labels = torch.ones(len(y_test))
for i , x in enumerate(zip(X_test, y_test)):
    object_to_classify, object_label = x
    pred_labels[i] = knn_classifier(torch.tensor(object_to_classify), 10, X_train, y_train)

# %%
fn_accuracy(torch.tensor(y_test), pred_labels)
# Out:
# 96.66666666666667

# %%
for i in range(32):
    object_to_classify = torch.tensor([random.uniform(4.2,8),
                                       random.uniform(2,4.5),
                                       random.uniform(1,7),
                                       random.uniform(0,2.6)])
    print(f'object {i+1} features: {object_to_classify}')
    object_label = knn_classifier(object_to_classify, 10, X_train, y_train)
    print(f'object {i+1} label: {names[object_label]}', end='\n-----------------\n')
# Out:
# object 1 features: tensor([4.7480, 3.8368, 1.0272, 2.5683])
# object 1 label: setosa
# -----------------
# object 2 features: tensor([6.1175, 3.4774, 4.1844, 0.4554])
# object 2 label: versicolor
# -----------------
# object 3 features: tensor([5.7958, 3.0835, 1.1858, 1.6313])
# object 3 label: setosa
# -----------------
# object 4 features: tensor([6.1910, 4.2392, 6.3958, 2.3592])
# object 4 label: virginica
# -----------------
# object 5 features: tensor([4.5471, 3.0125, 5.7204, 1.0933])
# object 5 label: versicolor
# -----------------
# object 6 features: tensor([7.5250, 3.9452, 2.9982, 1.0831])
# object 6 label: versicolor
# -----------------
# object 7 features: tensor([6.7674, 2.8664, 4.2589, 2.5667])
# object 7 label: virginica
# -----------------
# object 8 features: tensor([6.3659, 4.0473, 1.4018, 1.1021])
# object 8 label: setosa
# -----------------
# object 9 features: tensor([5.2021, 2.3212, 6.8623, 1.6248])
# object 9 label: virginica
# -----------------
# object 10 features: tensor([7.1692, 3.8623, 1.8031, 2.4865])
# object 10 label: setosa
# -----------------
# object 11 features: tensor([7.2043, 2.2790, 1.2048, 2.4920])
# object 11 label: setosa
# -----------------
# object 12 features: tensor([5.1268, 3.6663, 4.7638, 0.9594])
# object 12 label: versicolor
# -----------------
# object 13 features: tensor([4.9070, 3.4154, 5.3522, 1.3361])
# object 13 label: versicolor
# -----------------
# object 14 features: tensor([6.0686, 4.4698, 5.0051, 0.8713])
# object 14 label: versicolor
# -----------------
# object 15 features: tensor([6.2141, 2.2617, 1.2488, 0.3110])
# object 15 label: setosa
# -----------------
# object 16 features: tensor([4.6436, 3.5667, 5.0732, 1.1931])
# object 16 label: versicolor
# -----------------
# object 17 features: tensor([4.9310, 2.6430, 3.2442, 1.9529])
# object 17 label: versicolor
# -----------------
# object 18 features: tensor([5.3370, 3.8653, 1.3556, 2.2013])
# object 18 label: setosa
# -----------------
# object 19 features: tensor([6.7950, 2.6466, 3.1209, 1.4478])
# object 19 label: versicolor
# -----------------
# object 20 features: tensor([5.1164, 3.7318, 3.3732, 1.7306])
# object 20 label: versicolor
# -----------------
# object 21 features: tensor([5.4069, 3.7854, 1.4023, 0.8112])
# object 21 label: setosa
# -----------------
# object 22 features: tensor([4.7667, 2.1573, 5.7752, 2.1662])
# object 22 label: virginica
# -----------------
# object 23 features: tensor([7.1376, 3.8351, 5.8891, 0.3825])
# object 23 label: virginica
# -----------------
# object 24 features: tensor([5.8168, 4.1086, 4.2782, 1.9803])
# object 24 label: versicolor
# -----------------
# object 25 features: tensor([4.4890, 3.2990, 2.4788, 0.6050])
# object 25 label: setosa
# -----------------
# object 26 features: tensor([5.7027, 2.1037, 4.8156, 0.7294])
# object 26 label: versicolor
# -----------------
# object 27 features: tensor([7.1869, 2.0032, 1.2895, 1.8086])
# object 27 label: setosa
# -----------------
# object 28 features: tensor([6.5679, 2.3796, 1.3570, 0.6114])
# object 28 label: setosa
# -----------------
# object 29 features: tensor([4.7214, 3.2552, 4.0107, 0.5179])
# object 29 label: versicolor
# -----------------
# object 30 features: tensor([7.9532, 4.0825, 4.3058, 0.8580])
# object 30 label: versicolor
# -----------------
# object 31 features: tensor([4.7666, 3.2126, 2.6237, 2.1961])
# object 31 label: versicolor
# -----------------
# object 32 features: tensor([6.9104, 4.4054, 5.2181, 0.4967])
# object 32 label: versicolor
# -----------------
