# %% [markdown]
# <a href="https://colab.research.google.com/github/Temerius/ML/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pandas as pd
import random

# %%
from sklearn.datasets import load_iris

iris = load_iris()

# %%
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']
X.shape, y.shape, names, feature_names
# Out:
# ((150, 4),
#  (150,),
#  array(['setosa', 'versicolor', 'virginica'], dtype='<U10'),
#  ['sepal length (cm)',
#   'sepal width (cm)',
#   'petal length (cm)',
#   'petal width (cm)'])

# %%
d = {feature_names[i]: X[:,i] for i in range(4)}
iris_info = pd.DataFrame(d)
iris_info
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
target_names = [names[y[i]] for i in range(X.shape[0])]
iris_info['labels'] = y
iris_info['labels_name'] = target_names
iris_info
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      labels labels_name
# 0         0      setosa
# 1         0      setosa
# 2         0      setosa
# 3         0      setosa
# 4         0      setosa
# ..      ...         ...
# 145       2   virginica
# 146       2   virginica
# 147       2   virginica
# 148       2   virginica
# 149       2   virginica
#
# [150 rows x 6 columns]

# %%
iris_info.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      labels
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
def knn_classifier(object_to_classify, k, plan_matrix=X, targets=y):
    distances = torch.sum((object_to_classify.unsqueeze(0) - plan_matrix) ** 2, dim=1)
    _, min_indices = torch.topk(distances, k=k, largest=False)
    k_labels = targets[min_indices]
    label, _ = torch.mode(torch.tensor(k_labels))
    #print(min_indices, k_labels, label, distances)
    return label

# %%
for i in range(32):
    object_to_classify = torch.tensor([random.uniform(4.2,8),
                                       random.uniform(2,4.5),
                                       random.uniform(1,7),
                                       random.uniform(0,2.6)])
    print(f'object {i+1} features: {object_to_classify}')
    object_label = knn_classifier(object_to_classify, 10)
    print(f'object {i+1} label: {names[object_label]}', end='\n-----------------\n')
# Out:
# object 1 features: tensor([7.1983, 3.0078, 5.7323, 1.7489])
# object 1 label: virginica
# -----------------
# object 2 features: tensor([7.4063, 4.2339, 2.9669, 0.9219])
# object 2 label: versicolor
# -----------------
# object 3 features: tensor([7.4484, 4.4322, 4.5954, 0.5199])
# object 3 label: versicolor
# -----------------
# object 4 features: tensor([4.2446, 4.2354, 4.3835, 0.5123])
# object 4 label: versicolor
# -----------------
# object 5 features: tensor([4.2824, 3.5802, 6.0274, 0.8006])
# object 5 label: virginica
# -----------------
# object 6 features: tensor([6.9928, 2.0637, 1.6286, 0.6405])
# object 6 label: setosa
# -----------------
# object 7 features: tensor([6.5250, 3.1691, 3.1102, 0.4947])
# object 7 label: versicolor
# -----------------
# object 8 features: tensor([4.4803, 3.6690, 3.6210, 0.5646])
# object 8 label: versicolor
# -----------------
# object 9 features: tensor([5.9291, 2.7964, 1.8352, 1.4676])
# object 9 label: setosa
# -----------------
# object 10 features: tensor([5.2593, 4.3350, 2.5958, 2.3472])
# object 10 label: setosa
# -----------------
# object 11 features: tensor([6.7331, 3.1000, 1.6221, 0.6348])
# object 11 label: setosa
# -----------------
# object 12 features: tensor([6.2323, 2.7030, 4.4677, 0.8633])
# object 12 label: versicolor
# -----------------
# object 13 features: tensor([7.6326, 3.3506, 5.0895, 0.6620])
# object 13 label: versicolor
# -----------------
# object 14 features: tensor([6.4375, 3.6446, 6.7339, 0.7703])
# object 14 label: virginica
# -----------------
# object 15 features: tensor([4.8912, 3.6837, 1.7210, 0.0710])
# object 15 label: setosa
# -----------------
# object 16 features: tensor([6.8704, 4.0616, 3.4445, 0.3794])
# object 16 label: versicolor
# -----------------
# object 17 features: tensor([6.2997, 3.6549, 5.0998, 1.3260])
# object 17 label: versicolor
# -----------------
# object 18 features: tensor([6.0830, 2.0557, 1.6186, 1.6950])
# object 18 label: setosa
# -----------------
# object 19 features: tensor([5.2723, 4.0309, 2.7279, 0.5793])
# object 19 label: setosa
# -----------------
# object 20 features: tensor([7.3604, 2.0122, 2.4496, 2.2810])
# object 20 label: versicolor
# -----------------
# object 21 features: tensor([4.8200, 4.0801, 4.4802, 1.4641])
# object 21 label: versicolor
# -----------------
# object 22 features: tensor([7.8616, 2.8054, 1.6009, 0.5146])
# object 22 label: setosa
# -----------------
# object 23 features: tensor([6.3371, 4.4716, 2.0987, 0.4546])
# object 23 label: setosa
# -----------------
# object 24 features: tensor([6.3584, 2.9017, 4.6199, 0.6436])
# object 24 label: versicolor
# -----------------
# object 25 features: tensor([6.6857, 4.0881, 6.3668, 2.2090])
# object 25 label: virginica
# -----------------
# object 26 features: tensor([5.7106, 2.8264, 4.7145, 1.2114])
# object 26 label: versicolor
# -----------------
# object 27 features: tensor([6.0435, 4.1563, 5.5847, 0.3251])
# object 27 label: versicolor
# -----------------
# object 28 features: tensor([5.0744, 2.4110, 3.9620, 2.4232])
# object 28 label: versicolor
# -----------------
# object 29 features: tensor([4.9860, 2.0578, 6.9278, 1.5926])
# object 29 label: virginica
# -----------------
# object 30 features: tensor([4.6370, 3.1099, 2.9000, 2.2086])
# object 30 label: versicolor
# -----------------
# object 31 features: tensor([7.4813, 2.4132, 1.6487, 0.0096])
# object 31 label: setosa
# -----------------
# object 32 features: tensor([6.1259, 4.4946, 3.2809, 0.3788])
# object 32 label: setosa
# -----------------
